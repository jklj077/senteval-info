# %%
# %matplotlib notebook
import parse

# %%
parse.parse("logs/log-first-bert-base-uncased.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
parse.parse("logs/log-last-bert-base-uncased.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
parse.parse("logs/log-max-bert-base-uncased.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# E:\renxc\source\repos\senteval-info\parse.py:24: RuntimeWarning: invalid value encountered in true_divide
#   )[np.newaxis, :]
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
parse.parse("logs/log-mean-bert-base-uncased.txt")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
